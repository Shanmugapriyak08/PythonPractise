# %%
import pandas as pd
import numpy as np

# %%
telecom_data= pd.read_csv('Telecom retention_Telco Company .csv')

# %%
telecom_data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
pd.set_option('display.precision',2)

# %%
telecom_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# # Exploratory data

# %%
telecom_data.shape
# Out:
# (2666, 20)

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
# to change datatype of column
telecom_data['Churn']=telecom_data['Churn'].astype('int64')

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
telecom_data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# it is better to copy the data and work on that 
df=telecom_data.copy()

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         2666.00    2666.00                2666.00            2666.00
# mean           100.62     437.44                   8.02             179.48
# std             39.56      42.52                  13.61              54.21
# min              1.00     408.00                   0.00               0.00
# 25%             73.00     408.00                   0.00             143.40
# 50%            100.00     415.00                   0.00             179.95
# 75%            127.00     510.00                  19.00             215.90
# max            243.00     510.00                  50.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          2666.00           2666.00            2666.00          2666.00
# mean            100.31             30.51             200.39           100.02
# ...

# %%
# avg of day, evng, ni8 call = 100.31,100.02,100.11
# avg charges of day, evng, ni8 call = 30.51,17.03,9.05
# standard charge  approx - 20 each

# %%
mrng_call_customer = 100.31/30.51
mrng_call_customer
# Out:
# 3.2877745001638807

# %%
evng_call_customer=100.02/17.03
evng_call_customer
# Out:
# 5.873165002935995

# %%
ni8_call_customer=100.11/9.05
ni8_call_customer
# Out:
# 11.061878453038673

# %%
# above is customer spend in avg per call

# %%
df.describe(include=['bool','object'])
# Out:
#        State International plan Voice mail plan
# count   2666               2666            2666
# unique    51                  2               2
# top       WV                 No              No
# freq      88               2396            1933

# %%
df.describe(include='all')
# Out:
#        State  Account length  Area code International plan Voice mail plan  \
# count   2666         2666.00    2666.00               2666            2666
# unique    51             NaN        NaN                  2               2
# top       WV             NaN        NaN                 No              No
# freq      88             NaN        NaN               2396            1933
# mean     NaN          100.62     437.44                NaN             NaN
# std      NaN           39.56      42.52                NaN             NaN
# min      NaN            1.00     408.00                NaN             NaN
# 25%      NaN           73.00     408.00                NaN             NaN
# 50%      NaN          100.00     415.00                NaN             NaN
# 75%      NaN          127.00     510.00                NaN             NaN
# max      NaN          243.00     510.00                NaN             NaN
#
#         Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.Churn.value_counts()
# 2278- retained customer
# 388 - churned customer
# Out:
# 0    2278
# 1     388
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# 0    2278
# 1     388
# Name: Churn, dtype: int64

# %%
# we are able to findout the ratio of churned customer
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.85
# 1    0.15
# Name: Churn, dtype: float64

# %%
# retained customers based on total day charges
df.sort_values(by=['Churn','Total day charge'], ascending=[True,False]).head(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1818    NC             210        415                 No             Yes
# 460     SD             114        415                 No             Yes
# 2302    AL             141        510                 No             Yes
# 917     VT              50        415                Yes             Yes
# 1997    TN             123        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1818                     31              313.8               87
# 460                      36              309.9               90
# 2302                     28              308.0              123
# 917                      26              307.1               94
# 1997                     34              305.2               80
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# avg mean of churned customers
df['Churn'].mean()
# Out:
# 0.145536384096024

# %%
# average of all numerical value of churned customer
df[df['Churn']==1].mean()
# Out:
# Account length            102.32
# Area code                 437.54
# Number vmail messages       5.17
# Total day minutes         205.18
# Total day calls           101.20
# Total day charge           34.88
# Total eve minutes         209.39
# Total eve calls            99.95
# Total eve charge           17.80
# Total night minutes       205.31
# Total night calls         100.68
# Total night charge          9.24
# Total intl minutes         10.82
# Total intl calls            4.05
# Total intl charge           2.92
# Customer service calls      2.21
# Churn                       1.00
# dtype: float64

# %%
# Retained customers
df[df['Churn']==0].mean()
# Out:
# Account length            100.33
# Area code                 437.42
# Number vmail messages       8.51
# Total day minutes         175.10
# Total day calls           100.16
# Total day charge           29.77
# Total eve minutes         198.85
# Total eve calls           100.04
# Total eve charge           16.90
# Total night minutes       200.46
# Total night calls         100.01
# Total night charge          9.02
# Total intl minutes         10.14
# Total intl calls            4.54
# Total intl charge           2.74
# Customer service calls      1.45
# Churn                       0.00
# dtype: float64

# %%
# how many time customer spends in day call
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 205.1811855670104

# %%
# how much customer spends per day call
df[df['Churn']==1]['Total day charge'].mean()
# Out:
# 34.88134020618558

# %%
# how much loyal customer spends on International Calls
df[df['Churn']==0]['Total intl calls'].mean()
# Out:
# 4.53819139596137

# %%
# those who are not having International plan are churned out
df[(df['Churn']==1) & (df['International plan']=='No')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# 58      TX             150        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2614    ID              82        415                 No              No
# 2624    AR              76        408                 No              No
# 2628    KS             170        415                 No             Yes
# 2657    MD              62        408                 No              No
# 2658    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# to map the value in dataset

# %%
# imputting the categorial values to boolean values
f={'Yes':True,'No':False}

# %%
f
# Out:
# {'Yes': True, 'No': False}

# %%
df['International plan']=df['International plan'].map(f)

# %%
df
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415               False             Yes
# 1       OH             107        415               False             Yes
# 2       NJ             137        415               False              No
# 3       OH              84        408                True              No
# 4       OK              75        415                True              No
# ...    ...             ...        ...                 ...             ...
# 2661    SC              79        415               False              No
# 2662    AZ             192        415               False             Yes
# 2663    WV              68        415               False              No
# 2664    RI              28        510               False              No
# 2665    TN              74        415               False             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df=df.replace({'Voice mail plan':f})

# %%
df
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 2661    SC              79        415               False            False
# 2662    AZ             192        415               False             True
# 2663    WV              68        415               False            False
# 2664    RI              28        510               False            False
# 2665    TN              74        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   bool
#  4   Voice mail plan         2666 non-null   bool
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
# total calls
calls=['Total day calls','Total eve calls','Total night calls']
df.groupby('Churn')[calls].describe()
# Out:
#       Total day calls                                                 \
#                 count    mean    std  min   25%    50%    75%    max
# Churn
# 0              2278.0  100.16  19.68  0.0  87.0  100.0  113.0  160.0
# 1               388.0  101.20  21.71  0.0  87.0  103.0  116.0  156.0
#
#       Total eve calls          ...               Total night calls          \
#                 count    mean  ...    75%    max             count    mean
# Churn                          ...
# 0              2278.0  100.04  ...  114.0  170.0            2278.0  100.01
# 1               388.0   99.95  ...  113.0  159.0             388.0  100.68
#
#
#          std   min    25%    50%    75%    max
# Churn
# 0      19.31  33.0  87.00  100.0  113.0  166.0
# 1      20.07  49.0  85.75  101.0  116.0  158.0
#
# [2 rows x 24 columns]

# %%
# total calls
calls=['Total day calls','Total eve calls','Total night calls']
df.groupby('Churn')[calls].agg([np.mean,np.std,np.max,np.min])
# Out:
#       Total day calls                  Total eve calls                   \
#                  mean    std amax amin            mean    std amax amin
# Churn
# 0              100.16  19.68  160    0          100.04  20.26  170    0
# 1              101.20  21.71  156    0           99.95  19.61  159   48
#
#       Total night calls
#                    mean    std amax amin
# Churn
# 0                100.01  19.31  166   33
# 1                100.68  20.07  158   49

# %%
pd.crosstab(df['Churn'],df['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2126    152
# 1                     270    118

# %%
pd.crosstab(df['Churn'],df['Voice mail plan'])
# Out:
# Voice mail plan  False  True
# Churn
# 0                 1610    668
# 1                  323     65

# %%
df.pivot_table(calls,['State'],aggfunc='mean').sort_index(ascending=False)
# Out:
#        Total day calls  Total eve calls  Total night calls
# State
# WY              101.33            99.17             102.79
# WV              104.50            99.36             100.72
# WI               97.00            99.08              98.43
# WA              100.52            95.75             103.75
# VT              101.04            96.98             103.58
# VA              105.91           100.46              93.10
# UT               99.68            97.87             100.73
# TX              101.24           101.25              99.29
# TN               99.66           105.85              91.00
# SD               93.92            98.37              94.08
# SC              101.57           100.71              99.82
# RI              100.88            93.27             101.75
# PA               98.89           100.36              99.50
# OR               94.56            98.56             102.21
# OK               99.81           105.06             101.94
# ...

# %%
df.pivot_table(calls,['Area code'])
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                 100.78            99.56              98.56
# 415                 100.23           100.61             100.75
# 510                 100.01            99.33             100.38

# %%
df.groupby(['State','Area code'])[calls].mean()
# Out:
#                  Total day calls  Total eve calls  Total night calls
# State Area code
# AK    408                  95.33           103.56             108.56
#       415                  97.71            93.67              96.52
#       510                  89.15            93.08              93.31
# AL    408                  99.59            99.50              98.91
#       415                 103.50            98.38              98.41
# ...                          ...              ...                ...
# WV    415                 104.52            98.41             102.87
#       510                 102.59           104.56              97.07
# WY    408                  94.07           100.67              96.87
#       415                 103.14            98.54             105.83
#       510                 104.19            99.12             101.69
#
# [153 rows x 3 columns]

# %%
df.groupby(['State','Area code','Churn'])[calls].mean()
# Out:
#                        Total day calls  Total eve calls  Total night calls
# State Area code Churn
# AK    408       0                95.33           103.56             108.56
#       415       0                99.00            92.67              96.94
#                 1                90.00            99.67              94.00
#       510       0                89.15            93.08              93.31
# AL    408       0                99.00           102.44             101.11
# ...                                ...              ...                ...
# WY    408       0                94.07           100.67              96.87
#       415       0               103.77            99.97             103.70
#                 1                99.40            90.00             118.60
#       510       0               104.08            99.69             104.62
#                 1               104.67            96.67              89.00
#
# [285 rows x 3 columns]

# %%
# correlation between the churn and the its columns
df.corr()['Churn']
# Out:
# Account length            1.77e-02
# Area code                 1.02e-03
# International plan        2.77e-01
# Voice mail plan          -9.93e-02
# Number vmail messages    -8.65e-02
# Total day minutes         1.96e-01
# Total day calls           1.83e-02
# Total day charge          1.96e-01
# Total eve minutes         7.29e-02
# Total eve calls          -1.54e-03
# Total eve charge          7.29e-02
# Total night minutes       3.36e-02
# Total night calls         1.23e-02
# Total night charge        3.36e-02
# Total intl minutes        8.62e-02
# Total intl calls         -6.99e-02
# Total intl charge         8.62e-02
# Customer service calls    2.03e-01
# Churn                     1.00e+00
# Name: Churn, dtype: float64

# %%
threshold=0.7
abs(df.corr()['Churn'])#>threshold
# Out:
# Account length            1.77e-02
# Area code                 1.02e-03
# International plan        2.77e-01
# Voice mail plan           9.93e-02
# Number vmail messages     8.65e-02
# Total day minutes         1.96e-01
# Total day calls           1.83e-02
# Total day charge          1.96e-01
# Total eve minutes         7.29e-02
# Total eve calls           1.54e-03
# Total eve charge          7.29e-02
# Total night minutes       3.36e-02
# Total night calls         1.23e-02
# Total night charge        3.36e-02
# Total intl minutes        8.62e-02
# Total intl calls          6.99e-02
# Total intl charge         8.62e-02
# Customer service calls    2.03e-01
# Churn                     1.00e+00
# Name: Churn, dtype: float64
