# %% [markdown]
# ## matlpotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.DataFrame(np.random.rand(50,4),columns=('a','b','c','d'))

# %%
df1
# Out:
#            a         b         c         d
# 0   0.433024  0.667576  0.551617  0.140375
# 1   0.234434  0.480912  0.916695  0.347535
# 2   0.886224  0.891239  0.110351  0.481068
# 3   0.532192  0.411517  0.644594  0.282833
# 4   0.706080  0.316940  0.848228  0.021769
# 5   0.145438  0.055532  0.267649  0.321862
# 6   0.001834  0.703512  0.921953  0.756995
# 7   0.822463  0.547400  0.943674  0.197233
# 8   0.932694  0.487322  0.877367  0.292133
# 9   0.801592  0.490975  0.143640  0.743058
# 10  0.161841  0.765135  0.689352  0.991913
# 11  0.265950  0.408842  0.860714  0.992425
# 12  0.220255  0.877242  0.880883  0.144265
# 13  0.579200  0.433593  0.148753  0.273191
# 14  0.101303  0.754207  0.800048  0.508591
# 15  0.819935  0.778309  0.617079  0.885558
# 16  0.227588  0.331763  0.912207  0.159370
# 17  0.921157  0.145057  0.893615  0.303637
# 18  0.265969  0.114306  0.864494  0.303554
# 19  0.613284  0.041345  0.198867  0.168908
# 20  0.920738  0.104986  0.960670  0.083353
# ...

# %%
plt.histogram(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-49f23c1a989a> in <module>
# ----> 1 plt.histogram(df1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histogram'
