# %%
import requests
from bs4 import BeautifulSoup as bs

from urllib.request import urlopen as uReq
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
wiki_url = "https://en.wikipedia.org/wiki/" + "star" # preparing the URL to search the product on flipkart
uClient = uReq(wiki_url) # requesting the webpage from the internet
wikiPage = uClient.read()

# %%
wikiPage
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Star - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"5eb56f80-ed71-4806-bb53-107b43c9d481","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Star","wgTitle":"Star","wgCurRevisionId":1062528126,"wgRevisionId":1062528126,"wgArticleId":26808,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely semi-protected pages","Featured articles","Pages using multiple image
# ...

# %%
wiki_html = bs(wikiPage, "html.parser")

# %%
wiki_html
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Star - Wikipedia</title>
# ...

# %%
paragraph=wiki_html.findAll("p")

# %%
paragraph
# Out:
# [<p class="mw-empty-elt">
#  </p>,
# ...

# %%
len(paragraph)
# Out:
# 118

# %%
paragraph[3]
# Out:
# <p>Almost all naturally occurring <a href="/wiki/Chemical_element" title="Chemical element">elements</a> heavier than <a href="/wiki/Lithium" title="Lithium">lithium</a> are created by <a href="/wiki/Stellar_nucleosynthesis" title="Stellar nucleosynthesis">stellar nucleosynthesis</a> in stars or their remnants. Chemically enriched material is returned to the <a href="/wiki/Interstellar_medium" title="Interstellar medium">interstellar medium</a> by <a href="/wiki/Stellar_mass_loss" title="Stellar mass loss">stellar mass loss</a> or <a href="/wiki/Supernova" title="Supernova">supernova</a> explosions and then recycled into new stars.  Astronomers can determine stellar properties including mass, age, <a href="/wiki/Metallicity" title="Metallicity">metallicity</a> (chemical composition), <a href="/wiki/Variable_star" title="Variable star">variability</a>, <a class="mw-redirect" href="/wiki/Distance_(astronomy)" title="Distance (astronomy)">distance</a>, and motion through <a href="/wiki/
# ...

# %%
link = paragraph[7]

# %%
link
# Out:
# <p>Early astronomers recognized a difference between "<a href="/wiki/Fixed_stars" title="Fixed stars">fixed stars</a>", whose position on the <a href="/wiki/Celestial_sphere" title="Celestial sphere">celestial sphere</a> does not change, and "wandering stars" (<a href="/wiki/Planet" title="Planet">planets</a>), which move noticeably relative to the fixed stars over days or weeks.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> Many ancient astronomers believed that the stars were permanently affixed to a <a class="mw-redirect" href="/wiki/Heavenly_sphere" title="Heavenly sphere">heavenly sphere</a> and that they were immutable. By convention, astronomers grouped prominent stars into <a href="/wiki/Asterism_(astronomy)" title="Asterism (astronomy)">asterisms</a> and <a href="/wiki/Constellation" title="Constellation">constellations</a> and used them to track the motions of the planets and the inferred position of the Sun.<sup class="reference" id="cite_ref-f
# ...

# %%
for i in link:
    if  '<a href="#' in i :
        pass
    else:
        print(i)
    #x = txt.startswith("Hello")
# Out:
# Early astronomers recognized a difference between "
# <a href="/wiki/Fixed_stars" title="Fixed stars">fixed stars</a>
# ", whose position on the
# <a href="/wiki/Celestial_sphere" title="Celestial sphere">celestial sphere</a>
#  does not change, and "wandering stars" (
# <a href="/wiki/Planet" title="Planet">planets</a>
# ), which move noticeably relative to the fixed stars over days or weeks.
# <sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
#  Many ancient astronomers believed that the stars were permanently affixed to a
# <a class="mw-redirect" href="/wiki/Heavenly_sphere" title="Heavenly sphere">heavenly sphere</a>
#  and that they were immutable. By convention, astronomers grouped prominent stars into
# <a href="/wiki/Asterism_(astronomy)" title="Asterism (astronomy)">asterisms</a>
#  and
# <a href="/wiki/Constellation" title="Constellation">constellations</a>
#  and used them to track the motions of the planets and the inferred position of the Sun.
# ...

# %%
for i in link:
    if  '<a href="#' in i :
        i.replace()
    else:
        print(i)
    #x = txt.startswith("Hello")

# %%
link7=link.findAll("a")

# %%
link7
# Out:
# [<a href="/wiki/Fixed_stars" title="Fixed stars">fixed stars</a>,
#  <a href="/wiki/Celestial_sphere" title="Celestial sphere">celestial sphere</a>,
#  <a href="/wiki/Planet" title="Planet">planets</a>,
#  <a href="#cite_note-4">[4]</a>,
#  <a class="mw-redirect" href="/wiki/Heavenly_sphere" title="Heavenly sphere">heavenly sphere</a>,
#  <a href="/wiki/Asterism_(astronomy)" title="Asterism (astronomy)">asterisms</a>,
#  <a href="/wiki/Constellation" title="Constellation">constellations</a>,
#  <a href="#cite_note-forbes-2">[2]</a>,
#  <a href="/wiki/Solar_calendar" title="Solar calendar">calendars</a>,
#  <a href="#cite_note-5">[5]</a>,
#  <a href="/wiki/Gregorian_calendar" title="Gregorian calendar">Gregorian calendar</a>]

# %%
for i in link7:
    print(i.text)
# Out:
# fixed stars
# celestial sphere
# planets
# [4]
# heavenly sphere
# asterisms
# constellations
# [2]
# calendars
# [5]
# Gregorian calendar

# %%
for i in link7:
    if i.text[0]=='[':
        pass
    else :
        print(i.text)
# Out:
# fixed stars
# celestial sphere
# planets
# heavenly sphere
# asterisms
# constellations
# calendars
# Gregorian calendar

# %%
txt7= [i.text for i in link7 if not  i.text[0]=='[']

# %%
txt7
# Out:
# ['fixed stars',
#  'celestial sphere',
#  'planets',
#  'heavenly sphere',
#  'asterisms',
#  'constellations',
#  'calendars',
#  'Gregorian calendar']

# %%
link_replace=link.replace("", text7)

# %%
link
# Out:
# <p>Early astronomers recognized a difference between "<a href="/wiki/Fixed_stars" title="Fixed stars">fixed stars</a>", whose position on the <a href="/wiki/Celestial_sphere" title="Celestial sphere">celestial sphere</a> does not change, and "wandering stars" (<a href="/wiki/Planet" title="Planet">planets</a>), which move noticeably relative to the fixed stars over days or weeks.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> Many ancient astronomers believed that the stars were permanently affixed to a <a class="mw-redirect" href="/wiki/Heavenly_sphere" title="Heavenly sphere">heavenly sphere</a> and that they were immutable. By convention, astronomers grouped prominent stars into <a href="/wiki/Asterism_(astronomy)" title="Asterism (astronomy)">asterisms</a> and <a href="/wiki/Constellation" title="Constellation">constellations</a> and used them to track the motions of the planets and the inferred position of the Sun.<sup class="reference" id="cite_ref-f
# ...

# %%
for i in link:
    href=i.find("href")
    print(href)
# Out:
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1
# None
# -1

# %%
for i in link:
    aref=i.find("a")
    print(aref)
    if '<a href="#' in aref:
        remove.aref
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-2f2d490e8879> in <module>
#       2     aref=i.find("a")
#       3     print(aref)
# ----> 4     if '<a href="#' in aref:
#       5         remove.aref
#
# TypeError: argument of type 'int' is not iterable

# %%
image=wiki_html.findAll("img")

# %%
len(image)
# Out:
# 46

# %%
image
# Out:
# [<img alt="Featured article" data-file-height="438" data-file-width="462" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" width="20"/>,
#  <img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>,
# ...

# %%
link=wiki_html.findAll("a")

# %%
print(len(link))
# Out:
# 2548

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://en.wikipedia.org/wiki/Star")

links = driver.find_elements(By.TAG_NAME, "a")

print(len(links))
for i in links:
    print(i)

images=driver.find_elements(By.TAG_NAME, "img")

print(len(images))
for im in images:
    print(im)
# Out:
# 2548
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="bf20c0b0-81cc-43d9-905b-3323bcad18f2")>
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="92d5f3f7-d52e-44b2-bf26-3f3a676abe64")>
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="32e8baa5-0f08-4b4a-8f3e-11bb77457976")>
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="aea78b0a-8bb2-4b89-bf9b-f3ff71c7faeb")>
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="9827e38c-70fd-4719-bf60-96fdb630c1ad")>
# <selenium.webdriver.remote.webelement.WebElement (session="81f1e556e24db2b4aa499cf15b8c60ef", element="2b2cebd3-58f8-47ae-b15a-a0b0891b38d2")>
# ...
